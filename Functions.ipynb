# %% [markdown]
# # Functions

# %%
# Q1. Write a program to find addition of two numbers using functions
def add():
    a =10                 #logics
    b =20
    print(f'Sum of {a} and {b} is' ,a+b)
add()             #call the function

# %%
#witho out argument

# %%
def oddeven():
    a = int(input("Enter number:"))
    if(a%2 == 0):
        print("even")
    else:
        print("Odd number")
        
oddeven()

# %%
# Case 1 No argument no return

def add():
    a=10
    b=20
    c = a+b
    print("Add = ", c)
add()
# Case with argument no return

def add(a,b):

    c = a+b
    print("Add = ", c)
a=10
b=15
add(a,b)

# %%
#Lambda Function ==> Alambda function can take any number of arguments but can only have one exoression.
#syntax : Lambda arguments expression
x = lambda a,b : a*b;
print("Total Product is = ",x(3,4))

# %%
x = lambda a,b,c : a+b-c
print("Total = ",x(4,5,6))

# %%
x = lambda a: a+5
print("Total Value =",x(2))

# %%
# Filter function ==> the filter function function returns a iterator when a item are filtered through a function to test.
# if the otem is accepted return true else false
ages =[5,12,17,18,34,67,50]
def myfunc(x):
    if(x<18):
        return True
    else:
        return False
    
kid = list(filter(myfunc, ages))
print(kid) #output is in the list form
for x in kid:
    print(x)

# %%
#filter function calculate the subset of the data
#map function works on data
#Map Function() ==> The map() executes a specified function for each item in a iterable . The item is to the function as parmneter

# %%
a = ["3","45","89"]
for i in range(len(a)):
    a[i]  = int(a[i])
a[2] = a[2] +1
print(a[2])

# %%
b = list(map(int , a))
print(b)
b[2] = b[2] +1
print(b[2])

# %%
# Map func example
#method !
a = [1,2,3,4,5]
def sq(a):
    return a*a
square = list(map(sq,a))
print(square)

# %%
#method 2 using lambda
a = [1,2,3,4,5]
square = list(map(lambda x : x*x , a))
print(square)

# %%
# Reduce Function() == > The reduce function is used to apply a particular function paseed in its argument to all of the list elements
# mentioned in the sequence passed along, This function is defined in "Functools" module. At first step, first two elements of sequence are picked and the result is obtained

# %%
from functools import reduce
def myfunc(a,b):
    return a+b
val = [1,2,3,4,5]
add = reduce(myfunc, val)
print("Addition = ",add)

# %%
import cv2
import dlib
import numpy as np
import csv
import os
import time
import face_recognition
from datetime import datetime
from playsound import playsound

# Initialize the face detector from dlib
face_detector = dlib.get_frontal_face_detector()

pTime = 0
video_capture = cv2.VideoCapture(0)
Batch_name = "(BATCH-G)"

# Load known face encodings and names as you did before

VinayakDutt_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/Vinayak.jpg")
VinayakD_encoding = face_recognition.face_encodings(VinayakDutt_image)[0]

Vikas_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/Vikas.jpg")
Vikas_encoding = face_recognition.face_encodings(Vikas_image)[0]
 
Satayam_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/satayam.jpg")
Satayam_encoding = face_recognition.face_encodings(Satayam_image)[0]

VinayakS_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/VinayakS.jpg")
VinayakS_encoding = face_recognition.face_encodings(VinayakS_image)[0]

Saurabhsir_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/Saurabhsir.jpg")
Saurabhsir_encoding = face_recognition.face_encodings(Saurabhsir_image)[0]

Sanjeet_image = face_recognition.load_image_file("C:/Users/HP/OneDrive/Pictures/Camera Roll/sanjeet.jpg")
Sanjeet_encoding = face_recognition.face_encodings(Sanjeet_image)[0]
known_face_encoding = [
 VinayakD_encoding,
 Vikas_encoding,
 Satayam_encoding,
 VinayakS_encoding,
 Saurabhsir_encoding,
 Sanjeet_encoding,
]
 
known_faces_names = [
"Vinayak Dutt",
"Vikas ",
"Satayam Sharma ",
"Vinayak Sharma ",
"Saurabh ML Sir",
"Sanjeet",                  
]
batch = "(BATCH-G)"
students = known_faces_names.copy()
 
face_locations = []
face_encodings = []
face_names = []
s= True
 

now = datetime.now()
current_date = now.strftime("%Y-%m-%d")
 
 
 
f = open(current_date+'.csv','w+',newline = '')

lnwriter = csv.writer(f)

lnwriter = csv.writer(f)

# Add column headers
lnwriter.writerow(["Name", "Time","Batch"])  # Header row
 


# Rest of your code remains the same

while True:
    ret, frame = video_capture.read()

    cTime = time.time()
    fps = 1 / (cTime - pTime)
    pTime = cTime

    cv2.putText(frame, f'FPS: {int(fps)}', (20, 70), cv2.FONT_HERSHEY_PLAIN, 3, (0, 255, 0), 3)

    # Convert the frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Use the dlib face detector
    faces = face_detector(gray)

    for face in faces:
        x, y, w, h = face.left(), face.top(), face.width(), face.height()
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)

        # The rest of your face recognition code can stay the same
        col = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face_cap.detectMultiScale(
        col,
        scaleFactor = 1.1,
        minNeighbors = 5,
        minSize = (30, 30),
        flags = cv2.CASCADE_SCALE_IMAGE
    )
    
    for (x,y,w,h) in faces:
        
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)
        
    small_frame = cv2.resize(frame,(0,0),fx=0.25,fy=0.25)
    
    rgb_small_frame = np.ascontiguousarray(small_frame[:,:,::-1])
    
    if s:
        
        face_locations = face_recognition.face_locations(rgb_small_frame)
        
        face_encodings = face_recognition.face_encodings(rgb_small_frame,face_locations)
        
        face_names = []
        
        for face_encoding in face_encodings:
            
            matches = face_recognition.compare_faces(known_face_encoding,face_encoding)
            name=""
            
            face_distance = face_recognition.face_distance(known_face_encoding,face_encoding)
            
            best_match_index = np.argmin(face_distance)
            
            if matches[best_match_index]:
                name = known_faces_names[best_match_index]
 
            face_names.append(name)
    
            if name in known_faces_names:
                font = cv2.FONT_HERSHEY_TRIPLEX
                Text = (x+10,y+10)
                fontScale              = 1
                fontColor              = (255,0,255)
                thickness              = 2
                lineType               = 2
                if name != "Saurabh ML Sir":
                    cv2.putText(frame,name+' Present'+ batch, 
                            Text, 
                            font, 
                            fontScale,
                            fontColor,
                            thickness,
                            lineType)
                else:
                    cv2.putText(frame,name+' Present'+ "Batch : NA", 
                            Text, 
                            font, 
                            fontScale,
                            fontColor,
                            thickness,
                            lineType)
                if name in students :
                    students.remove(name)
            
                    print(students)
                
                    current_time = now.strftime("%H-%M-%S")
                    
                    lnwriter.writerow([name,current_time,batch if name != "Saurabh ML Sir" else "NA"])
            else:
                cv2.putText(frame,"Unknown Person", 
                   Text, 
                   font, 
                   fontScale,
                   fontColor,
                   thickness,
                   lineType)
                
                break
                   
    cv2.imshow("attendance system", frame)

    if cv2.waitKey(1) == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()
f.close()
